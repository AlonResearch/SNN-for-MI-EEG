# %%
import numpy as np 
import torch
import torch.utils.data as da
from torch import nn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import scipy.io as scio
#!pip install spikingjelly
from spikingjelly.activation_based import ann2snn
import matplotlib.pyplot as plt

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))
# !nvidia-smi
# Out:
# Using cpu device
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
#Defining functions

def data_loader(data, label, batch=64, shuffle=True, drop=False):
    """
    Preprocess the data to fit model.
    Feed data into data_loader.
    input:
        data (float): samples*length*ch (samples*ch*length).
        label (int): samples, ie.: [0, 1, 1, 0, ..., 2].
        batch (int): batch size
        shuffle (bool): shuffle data before input into decoder
        drop (bool): drop the last samples if True
    output:
        data loader
    """
    label = torch.LongTensor(label.flatten()).to(device)
    if data.shape[1] >= data.shape[2]:
        data = torch.tensor(data.swapaxes(1, 2))
    data = torch.unsqueeze(data, dim=1).type('torch.FloatTensor').to(device)
    data = da.TensorDataset(data, label)
    loader = da.DataLoader(dataset=data, batch_size=batch, shuffle=shuffle, drop_last=drop)
    return loader


def val_snn(Dec, test_loader, T=None):
    Dec.eval().to(device)
    correct = 0
    total = 0
    if T is not None:
        corrects = np.zeros(T)
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(test_loader):
            if T is None:
                outputs = Dec(inputs)
                correct += (outputs.argmax(dim=1) == targets.to(device)).float().sum().item()
            else:
                for m in Dec.modules():
                    if hasattr(m, 'reset'):
                        m.reset()
                for t in range(T):
                    if t == 0:
                        outputs = Dec(inputs)
                    else:
                        outputs += Dec(inputs)
                    corrects[t] += (outputs.argmax(dim=1) == targets.to(device)).float().sum().item()
            total += targets.shape[0]
    return correct / total if T is None else corrects / total


def anntosnn(ann_model, train_x, train_y, test_x, test_y, batch=64, T=None):
    # Define data loader
    train_loader = data_loader(train_x, train_y, batch=batch)
    test_loader = data_loader(test_x, test_y, batch=batch)

    print('---------------------------------------------')
    print('Converting using MaxNorm')
    model_converter = ann2snn.Converter(mode='max', dataloader=train_loader)
    snn_model = model_converter(ann_model)
    mode_max_accs = val_snn(snn_model, test_loader, T=T)

    return mode_max_accs


torch.backends.cudnn.benchmark = True

def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out", nonlinearity="relu")
        elif isinstance(m, (nn.BatchNorm2d, nn.GroupNorm)):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)


def train_ann(ann_model, train_x, train_y, test_x, test_y, ep=500, batch=64):
    """
    input:
        train_x, test_x (float): samples*length*ch (samples*ch*length).
        train_y, test_y (int): samples, ie.: [0, 1, 1, 0, ..., 2].
        ep (int): total train and test epoch
        batch (int): batch size
    output:
        train acc, test acc, weight_file
    """
    # Define training configuration
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(ann_model.parameters(), lr=0.01)
    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=ep)

    # Define data loader
    train_loader = data_loader(train_x, train_y, batch=batch)
    test_loader = data_loader(test_x, test_y, batch=batch)

    train_acc = []
    test_acc = []
    for epoch in range(ep):
        # Train ANN
        ann_model.train()
        train_loss = 0
        correct = 0
        total = 0
        loss = 0
        print('\n')
        for batch_idx, (inputs, targets) in enumerate(train_loader):
            optimizer.zero_grad()
            outputs = ann_model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
            print(batch_idx, len(train_loader), 'Epoch: %d | ANN: trainLoss: %.4f | trainAcc: %.4f%% (%d/%d)'
                  % (epoch, train_loss / (batch_idx + 1), 100. * correct / total, correct, total))

        lr_scheduler.step()
        train_acc.append(round(correct / total, 4))

        # Test ANN
        ann_model.eval()
        val_loss = 0
        correct = 0
        total = 0
        loss = 0
        with torch.no_grad():
            for batch_idx, (inputs, targets) in enumerate(test_loader):
                outputs = ann_model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total += targets.size(0)
                correct += predicted.eq(targets).sum().item()
                print(batch_idx, len(test_loader), 'Epoch: %d | ANN: testLoss: %.4f | testAcc: %.4f%% (%d/%d)'
                      % (epoch, val_loss / (batch_idx + 1), 100. * correct / total, correct, total))

        test_acc.append(round(correct / total, 4))

    train_acc = np.asarray(train_acc[-1])
    test_acc = np.asarray(test_acc[-1])
    return train_acc, test_acc,ann_model

# %%
# Model 2a

class LENet(nn.Module):
    """
        LENet Model
    input:
         data shape as: batch_size*1*channel*length (64*1*22*1000) BCI IV-2a
         batch_size：64
         channel：22
         length：1000
    output:
        classes_num
    """

    def __init__(self, classes_num=4):
        super(LENet, self).__init__()
        self.drop_out = 0.5

        self.block_TCB_1 = nn.Sequential(
            # Temporal Convolution block kernel_size (1,64) #
            nn.ZeroPad2d((32, 31, 0, 0)),
            nn.Conv2d(
                in_channels=1,
                out_channels=8,
                kernel_size=(1, 64),
                bias=False,
            ),
            nn.BatchNorm2d(8)
        )
        self.block_TCB_2 = nn.Sequential(
            # Temporal Convolution block kernel_size (1,32) #
            nn.ZeroPad2d((16, 15, 0, 0)),
            nn.Conv2d(
                in_channels=1,
                out_channels=8,
                kernel_size=(1, 32),
                bias=False,
            ),
            nn.BatchNorm2d(8)
        )
        self.block_TCB_3 = nn.Sequential(
            # Temporal Convolution block kernel_size (1,16) #
            nn.ZeroPad2d((8, 7, 0, 0)),
            nn.Conv2d(
                in_channels=1,
                out_channels=8,
                kernel_size=(1, 16),
                bias=False,
            ),
            nn.BatchNorm2d(8)
        )

        self.TCB_fusion = nn.Sequential(
            # Temporal Convolution block fusion kernel_size (1,1) #
            nn.Conv2d(
                in_channels=24,
                out_channels=24,
                kernel_size=(1, 1),
                bias=False,
            ),
            nn.BatchNorm2d(24)
        )

        self.SCB = nn.Sequential(
            # Spatial Convolution block kernel_size (channel,1) #
            nn.Conv2d(
                in_channels=24,
                out_channels=16,
                kernel_size=(22, 1),
                groups=8,
                bias=False
            ),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.AvgPool2d((1, 4)),
            nn.Dropout(self.drop_out)
        )

        self.FFCB = nn.Sequential(
            # Feature Fusion Convolution block kernel_size (1,16) and (1,1) #
            nn.ZeroPad2d((7, 8, 0, 0)),
            nn.Conv2d(
                in_channels=16,
                out_channels=16,
                kernel_size=(1, 16),
                groups=16,
                bias=False
            ),
            nn.Conv2d(
                in_channels=16,
                out_channels=16,
                kernel_size=(1, 1),
                bias=False
            ),  #
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.AvgPool2d((1, 8)),
            nn.Dropout(self.drop_out)
        )

        self.CCB = nn.Sequential(
            # Classification Convolution block kernel_size (1,1) #
            nn.Conv2d(
                in_channels=16,
                out_channels=classes_num,
                kernel_size=(1, 1),
                bias=False
            ),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
        )

    def forward(self, x):
        x1 = self.block_TCB_1(x)
        x2 = self.block_TCB_2(x)
        x3 = self.block_TCB_3(x)
        x4 = torch.cat([x1, x2, x3], dim=1)
        x = self.TCB_fusion(x4)
        x = self.SCB(x)
        x = self.FFCB(x)
        x = self.CCB(x)
        return x


class LENet_FCL(nn.Module):
    def __init__(self, classes_num=4):
        super(LENet_FCL, self).__init__()
        self.drop_out = 0.5
        self.block_TCB_1 = nn.Sequential(
            nn.ZeroPad2d((32, 31, 0, 0)),
            nn.Conv2d(
                in_channels=1,
                out_channels=8,
                kernel_size=(1, 64),
                bias=False,
            ),
            nn.BatchNorm2d(8)
        )
        self.block_TCB_2 = nn.Sequential(
            nn.ZeroPad2d((16, 15, 0, 0)),
            nn.Conv2d(
                in_channels=1,
                out_channels=8,
                kernel_size=(1, 32),
                bias=False,
            ),
            nn.BatchNorm2d(8)
        )
        self.block_TCB_3 = nn.Sequential(
            nn.ZeroPad2d((8, 7, 0, 0)),
            nn.Conv2d(
                in_channels=1,
                out_channels=8,
                kernel_size=(1, 16),
                bias=False,
            ),
            nn.BatchNorm2d(8)
        )

        self.TCB_fusion = nn.Sequential(
            nn.Conv2d(
                in_channels=24,
                out_channels=24,
                kernel_size=(1, 1),
                bias=False,
            ),
            nn.BatchNorm2d(24)
        )

        self.SCB = nn.Sequential(
            nn.Conv2d(
                in_channels=24,
                out_channels=16,
                kernel_size=(22, 1),
                groups=8,
                bias=False
            ),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.AvgPool2d((1, 4)),
            nn.Dropout(self.drop_out)
        )

        self.FFCB = nn.Sequential(
            nn.ZeroPad2d((7, 8, 0, 0)),
            nn.Conv2d(
                in_channels=16,
                out_channels=16,
                kernel_size=(1, 16),
                groups=16,
                bias=False
            ),
            nn.Conv2d(
                in_channels=16,
                out_channels=16,
                kernel_size=(1, 1),
                bias=False
            ),  #
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.AvgPool2d((1, 8)),
            nn.Dropout(self.drop_out)
        )

        self.FCL = nn.Sequential(
            nn.Flatten(),
            nn.Linear(16 * 31, classes_num)
        )

    def forward(self, x):
        x1 = self.block_TCB_1(x)
        x2 = self.block_TCB_2(x)
        x3 = self.block_TCB_3(x)
        x4 = torch.cat([x1, x2, x3], dim=1)
        x = self.TCB_fusion(x4)
        x = self.SCB(x)
        x = self.FFCB(x)
        x = self.FCL(x)
        return x

# %%
"""
ANN to SNN Conversion Framework execution
"""
# Hyperparameters
EPOCHS = 30
BATCH_SIZE = 64
TIME_STEPS = 100  # T for SNN
TEST_SIZE = 0.4

# Getting real samples
#Locally load the dataset
file = scio.loadmat('Datasets\BCICIV_2a_gdf\Derivatives\A01T.mat')

# Google Colab load the dataset
# file = scio.loadmat('/content/A01T.mat')
all_data = file['all_data']
all_label = file['all_label']

datasetX = torch.tensor(all_data, dtype=torch.float32)
datasetY = torch.tensor(all_label, dtype=torch.int64)
train_data, test_data, train_label, test_label = train_test_split(datasetX, datasetY, test_size=TEST_SIZE, shuffle=True,
                                                                  random_state=0)

# Initialize model
ann_model = LENet(classes_num=4).to(device)
ann_model.apply(initialize_weights)

# Train ANN model
train_acc, test_acc, model_trained = train_ann(ann_model, train_data, train_label, test_data, test_label, 
                                              ep=EPOCHS, batch=BATCH_SIZE)
max_norm_acc = anntosnn(model_trained, train_data, train_label, test_data, test_label, 
                        batch=BATCH_SIZE, T=TIME_STEPS)
snn_model = ann2snn.Converter(mode='max', dataloader=data_loader(train_data, train_label, batch=BATCH_SIZE))(model_trained)

print('\n')
print('ANN accuracy: Test: %.4f%%' % (test_acc * 100))
print('SNN accuracy: max_norm: %.4f%%' % (max_norm_acc[-1] * 100))
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\B'
# <>:12: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\User\AppData\Local\Temp\ipykernel_14308\3408461078.py:12: SyntaxWarning: invalid escape sequence '\B'
#   file = scio.loadmat('Datasets\BCICIV_2a_gdf\Derivatives\A01T.mat')
# 0 3 Epoch: 0 | ANN: trainLoss: 2.0420 | trainAcc: 20.3125% (13/64)
# 1 3 Epoch: 0 | ANN: trainLoss: 1.9462 | trainAcc: 21.8750% (28/128)
# 2 3 Epoch: 0 | ANN: trainLoss: 1.8256 | trainAcc: 23.8372% (41/172)
# 0 2 Epoch: 0 | ANN: testLoss: 1.4178 | testAcc: 26.5625% (17/64)
# 1 2 Epoch: 0 | ANN: testLoss: 1.4000 | testAcc: 25.8621% (30/116)
#
#
# 0 3 Epoch: 1 | ANN: trainLoss: 1.6296 | trainAcc: 28.1250% (18/64)
# 1 3 Epoch: 1 | ANN: trainLoss: 1.5980 | trainAcc: 25.7812% (33/128)
# 2 3 Epoch: 1 | ANN: trainLoss: 1.5902 | trainAcc: 25.0000% (43/172)
# 0 2 Epoch: 1 | ANN: testLoss: 1.5256 | testAcc: 17.1875% (11/64)
# 1 2 Epoch: 1 | ANN: testLoss: 1.4816 | testAcc: 24.1379% (28/116)
#
#
# 0 3 Epoch: 2 | ANN: trainLoss: 1.4419 | trainAcc: 21.8750% (14/64)
# 1 3 Epoch: 2 | ANN: trainLoss: 1.4487 | trainAcc: 19.5312% (25/128)
# 2 3 Epoch: 2 | ANN: trainLoss: 1.4218 | trainAcc: 20.9302% (36/172)
# 0 2 Epoch: 2 | ANN: testLoss: 1.6809 | testAcc: 26.5625% (17/64)
# 1 2 Epoch: 2 | ANN: testLoss: 1.6843 | testAcc: 25.8621% (30/116)
#
#
# 0 3 Epoch: 3 | ANN: trainLoss: 1.4478 | trainAcc: 23.4375% (15/64)
# 1 3 Epoch: 3 | ANN: trainLoss: 1.3943 | trainAcc: 28.9062% (37/128)
# 2 3 Epoch: 3 | ANN: trainLoss: 1.3593 | trainAcc: 31.9767% (55/172)
# 0 2 Epoch: 3 | ANN: testLoss: 1.8026 | testAcc: 25.0000% (16/64)
# 1 2 Epoch: 3 | ANN: testLoss: 1.8359 | testAcc: 25.8621% (30/116)
#
#
# 0 3 Epoch: 4 | ANN: trainLoss: 1.3561 | trainAcc: 31.2500% (20/64)
# 1 3 Epoch: 4 | ANN: trainLoss: 1.3349 | trainAcc: 34.3750% (44/128)
# 2 3 Epoch: 4 | ANN: trainLoss: 1.3415 | trainAcc: 34.3023% (59/172)
# 0 2 Epoch: 4 | ANN: testLoss: 1.9389 | testAcc: 28.1250% (18/64)
# 1 2 Epoch: 4 | ANN: testLoss: 1.9723 | testAcc: 26.7241% (31/116)
#
#
# 0 3 Epoch: 5 | ANN: trainLoss: 1.3123 | trainAcc: 42.1875% (27/64)
# 1 3 Epoch: 5 | ANN: trainLoss: 1.2916 | trainAcc: 42.9688% (55/128)
# 2 3 Epoch: 5 | ANN: trainLoss: 1.3015 | trainAcc: 42.4419% (73/172)
# 0 2 Epoch: 5 | ANN: testLoss: 1.8639 | testAcc: 28.1250% (18/64)
# 1 2 Epoch: 5 | ANN: testLoss: 1.9422 | testAcc: 26.7241% (31/116)
#
#
# 0 3 Epoch: 6 | ANN: trainLoss: 1.3830 | trainAcc: 28.1250% (18/64)
# 1 3 Epoch: 6 | ANN: trainLoss: 1.3250 | trainAcc: 36.7188% (47/128)
# 2 3 Epoch: 6 | ANN: trainLoss: 1.3015 | trainAcc: 37.2093% (64/172)
# 0 2 Epoch: 6 | ANN: testLoss: 1.9175 | testAcc: 25.0000% (16/64)
# 1 2 Epoch: 6 | ANN: testLoss: 1.7724 | testAcc: 25.8621% (30/116)
#
#
# 0 3 Epoch: 7 | ANN: trainLoss: 1.3537 | trainAcc: 28.1250% (18/64)
# 1 3 Epoch: 7 | ANN: trainLoss: 1.3746 | trainAcc: 30.4688% (39/128)
# 2 3 Epoch: 7 | ANN: trainLoss: 1.3690 | trainAcc: 30.8140% (53/172)
# 0 2 Epoch: 7 | ANN: testLoss: 1.7801 | testAcc: 23.4375% (15/64)
# 1 2 Epoch: 7 | ANN: testLoss: 1.6433 | testAcc: 25.8621% (30/116)
#
#
# 0 3 Epoch: 8 | ANN: trainLoss: 1.2938 | trainAcc: 31.2500% (20/64)
# 1 3 Epoch: 8 | ANN: trainLoss: 1.2966 | trainAcc: 34.3750% (44/128)
# 2 3 Epoch: 8 | ANN: trainLoss: 1.2887 | trainAcc: 34.3023% (59/172)
# 0 2 Epoch: 8 | ANN: testLoss: 1.5818 | testAcc: 32.8125% (21/64)
# 1 2 Epoch: 8 | ANN: testLoss: 1.5251 | testAcc: 29.3103% (34/116)
#
#
# 0 3 Epoch: 9 | ANN: trainLoss: 1.2914 | trainAcc: 39.0625% (25/64)
# 1 3 Epoch: 9 | ANN: trainLoss: 1.2813 | trainAcc: 39.0625% (50/128)
# 2 3 Epoch: 9 | ANN: trainLoss: 1.2901 | trainAcc: 38.3721% (66/172)
# 0 2 Epoch: 9 | ANN: testLoss: 1.4991 | testAcc: 37.5000% (24/64)
# 1 2 Epoch: 9 | ANN: testLoss: 1.4659 | testAcc: 34.4828% (40/116)
#
#
# 0 3 Epoch: 10 | ANN: trainLoss: 1.3111 | trainAcc: 34.3750% (22/64)
# 1 3 Epoch: 10 | ANN: trainLoss: 1.2987 | trainAcc: 39.0625% (50/128)
# 2 3 Epoch: 10 | ANN: trainLoss: 1.2887 | trainAcc: 37.7907% (65/172)
# 0 2 Epoch: 10 | ANN: testLoss: 1.4485 | testAcc: 37.5000% (24/64)
# 1 2 Epoch: 10 | ANN: testLoss: 1.4148 | testAcc: 36.2069% (42/116)
#
#
# 0 3 Epoch: 11 | ANN: trainLoss: 1.2473 | trainAcc: 35.9375% (23/64)
# 1 3 Epoch: 11 | ANN: trainLoss: 1.2277 | trainAcc: 39.8438% (51/128)
# 2 3 Epoch: 11 | ANN: trainLoss: 1.2455 | trainAcc: 40.6977% (70/172)
# 0 2 Epoch: 11 | ANN: testLoss: 1.4227 | testAcc: 31.2500% (20/64)
# 1 2 Epoch: 11 | ANN: testLoss: 1.3786 | testAcc: 38.7931% (45/116)
#
#
# 0 3 Epoch: 12 | ANN: trainLoss: 1.2373 | trainAcc: 45.3125% (29/64)
# 1 3 Epoch: 12 | ANN: trainLoss: 1.2207 | trainAcc: 46.0938% (59/128)
# 2 3 Epoch: 12 | ANN: trainLoss: 1.2313 | trainAcc: 45.3488% (78/172)
# 0 2 Epoch: 12 | ANN: testLoss: 1.3414 | testAcc: 37.5000% (24/64)
# 1 2 Epoch: 12 | ANN: testLoss: 1.3703 | testAcc: 35.3448% (41/116)
#
#
# 0 3 Epoch: 13 | ANN: trainLoss: 1.2200 | trainAcc: 40.6250% (26/64)
# 1 3 Epoch: 13 | ANN: trainLoss: 1.1849 | trainAcc: 47.6562% (61/128)
# 2 3 Epoch: 13 | ANN: trainLoss: 1.2002 | trainAcc: 47.0930% (81/172)
# 0 2 Epoch: 13 | ANN: testLoss: 1.4009 | testAcc: 37.5000% (24/64)
# 1 2 Epoch: 13 | ANN: testLoss: 1.3380 | testAcc: 37.0690% (43/116)
#
#
# 0 3 Epoch: 14 | ANN: trainLoss: 1.3122 | trainAcc: 32.8125% (21/64)
# 1 3 Epoch: 14 | ANN: trainLoss: 1.2633 | trainAcc: 40.6250% (52/128)
# 2 3 Epoch: 14 | ANN: trainLoss: 1.2466 | trainAcc: 38.9535% (67/172)
# 0 2 Epoch: 14 | ANN: testLoss: 1.3712 | testAcc: 32.8125% (21/64)
# 1 2 Epoch: 14 | ANN: testLoss: 1.3159 | testAcc: 37.9310% (44/116)
#
#
# 0 3 Epoch: 15 | ANN: trainLoss: 1.1948 | trainAcc: 45.3125% (29/64)
# 1 3 Epoch: 15 | ANN: trainLoss: 1.2073 | trainAcc: 46.0938% (59/128)
# 2 3 Epoch: 15 | ANN: trainLoss: 1.1926 | trainAcc: 45.9302% (79/172)
# 0 2 Epoch: 15 | ANN: testLoss: 1.2537 | testAcc: 43.7500% (28/64)
# 1 2 Epoch: 15 | ANN: testLoss: 1.3148 | testAcc: 37.9310% (44/116)
#
#
# 0 3 Epoch: 16 | ANN: trainLoss: 1.2203 | trainAcc: 46.8750% (30/64)
# 1 3 Epoch: 16 | ANN: trainLoss: 1.1828 | trainAcc: 48.4375% (62/128)
# 2 3 Epoch: 16 | ANN: trainLoss: 1.1855 | trainAcc: 45.9302% (79/172)
# 0 2 Epoch: 16 | ANN: testLoss: 1.2056 | testAcc: 43.7500% (28/64)
# 1 2 Epoch: 16 | ANN: testLoss: 1.2995 | testAcc: 39.6552% (46/116)
#
#
# 0 3 Epoch: 17 | ANN: trainLoss: 1.1662 | trainAcc: 53.1250% (34/64)
# 1 3 Epoch: 17 | ANN: trainLoss: 1.1238 | trainAcc: 56.2500% (72/128)
# 2 3 Epoch: 17 | ANN: trainLoss: 1.1482 | trainAcc: 52.9070% (91/172)
# 0 2 Epoch: 17 | ANN: testLoss: 1.2486 | testAcc: 39.0625% (25/64)
# 1 2 Epoch: 17 | ANN: testLoss: 1.2769 | testAcc: 37.9310% (44/116)
#
#
# 0 3 Epoch: 18 | ANN: trainLoss: 1.0817 | trainAcc: 53.1250% (34/64)
# 1 3 Epoch: 18 | ANN: trainLoss: 1.1147 | trainAcc: 50.0000% (64/128)
# 2 3 Epoch: 18 | ANN: trainLoss: 1.1711 | trainAcc: 47.6744% (82/172)
# 0 2 Epoch: 18 | ANN: testLoss: 1.3045 | testAcc: 35.9375% (23/64)
# 1 2 Epoch: 18 | ANN: testLoss: 1.2594 | testAcc: 40.5172% (47/116)
#
#
# 0 3 Epoch: 19 | ANN: trainLoss: 1.1186 | trainAcc: 48.4375% (31/64)
# 1 3 Epoch: 19 | ANN: trainLoss: 1.1552 | trainAcc: 48.4375% (62/128)
# 2 3 Epoch: 19 | ANN: trainLoss: 1.1421 | trainAcc: 49.4186% (85/172)
# 0 2 Epoch: 19 | ANN: testLoss: 1.2296 | testAcc: 40.6250% (26/64)
# 1 2 Epoch: 19 | ANN: testLoss: 1.2532 | testAcc: 43.1034% (50/116)
#
#
# 0 3 Epoch: 20 | ANN: trainLoss: 1.1355 | trainAcc: 45.3125% (29/64)
# 1 3 Epoch: 20 | ANN: trainLoss: 1.1363 | trainAcc: 46.8750% (60/128)
# 2 3 Epoch: 20 | ANN: trainLoss: 1.1399 | trainAcc: 46.5116% (80/172)
# 0 2 Epoch: 20 | ANN: testLoss: 1.2678 | testAcc: 42.1875% (27/64)
# 1 2 Epoch: 20 | ANN: testLoss: 1.2383 | testAcc: 43.9655% (51/116)
#
#
# 0 3 Epoch: 21 | ANN: trainLoss: 1.1534 | trainAcc: 40.6250% (26/64)
# 1 3 Epoch: 21 | ANN: trainLoss: 1.1237 | trainAcc: 46.8750% (60/128)
# 2 3 Epoch: 21 | ANN: trainLoss: 1.1545 | trainAcc: 44.7674% (77/172)
# 0 2 Epoch: 21 | ANN: testLoss: 1.2262 | testAcc: 39.0625% (25/64)
# 1 2 Epoch: 21 | ANN: testLoss: 1.2318 | testAcc: 41.3793% (48/116)
#
#
# 0 3 Epoch: 22 | ANN: trainLoss: 1.1289 | trainAcc: 48.4375% (31/64)
# 1 3 Epoch: 22 | ANN: trainLoss: 1.0974 | trainAcc: 50.0000% (64/128)
# 2 3 Epoch: 22 | ANN: trainLoss: 1.0678 | trainAcc: 51.7442% (89/172)
# 0 2 Epoch: 22 | ANN: testLoss: 1.2008 | testAcc: 46.8750% (30/64)
# 1 2 Epoch: 22 | ANN: testLoss: 1.2245 | testAcc: 40.5172% (47/116)
#
#
# 0 3 Epoch: 23 | ANN: trainLoss: 1.0679 | trainAcc: 53.1250% (34/64)
# 1 3 Epoch: 23 | ANN: trainLoss: 1.1088 | trainAcc: 49.2188% (63/128)
# 2 3 Epoch: 23 | ANN: trainLoss: 1.0808 | trainAcc: 52.3256% (90/172)
# 0 2 Epoch: 23 | ANN: testLoss: 1.1945 | testAcc: 40.6250% (26/64)
# 1 2 Epoch: 23 | ANN: testLoss: 1.2196 | testAcc: 43.1034% (50/116)
#
#
# 0 3 Epoch: 24 | ANN: trainLoss: 1.1479 | trainAcc: 40.6250% (26/64)
# 1 3 Epoch: 24 | ANN: trainLoss: 1.1189 | trainAcc: 46.8750% (60/128)
# 2 3 Epoch: 24 | ANN: trainLoss: 1.0923 | trainAcc: 47.6744% (82/172)
# 0 2 Epoch: 24 | ANN: testLoss: 1.2335 | testAcc: 43.7500% (28/64)
# 1 2 Epoch: 24 | ANN: testLoss: 1.2113 | testAcc: 42.2414% (49/116)
#
#
# 0 3 Epoch: 25 | ANN: trainLoss: 1.1471 | trainAcc: 48.4375% (31/64)
# 1 3 Epoch: 25 | ANN: trainLoss: 1.0877 | trainAcc: 55.4688% (71/128)
# 2 3 Epoch: 25 | ANN: trainLoss: 1.1047 | trainAcc: 54.0698% (93/172)
# 0 2 Epoch: 25 | ANN: testLoss: 1.2133 | testAcc: 46.8750% (30/64)
# 1 2 Epoch: 25 | ANN: testLoss: 1.2126 | testAcc: 43.1034% (50/116)
#
#
# 0 3 Epoch: 26 | ANN: trainLoss: 1.0855 | trainAcc: 48.4375% (31/64)
# 1 3 Epoch: 26 | ANN: trainLoss: 1.0591 | trainAcc: 52.3438% (67/128)
# 2 3 Epoch: 26 | ANN: trainLoss: 1.0708 | trainAcc: 51.7442% (89/172)
# 0 2 Epoch: 26 | ANN: testLoss: 1.2057 | testAcc: 46.8750% (30/64)
# 1 2 Epoch: 26 | ANN: testLoss: 1.2119 | testAcc: 44.8276% (52/116)
#
#
# 0 3 Epoch: 27 | ANN: trainLoss: 1.0303 | trainAcc: 62.5000% (40/64)
# 1 3 Epoch: 27 | ANN: trainLoss: 1.1077 | trainAcc: 53.9062% (69/128)
# 2 3 Epoch: 27 | ANN: trainLoss: 1.0957 | trainAcc: 55.2326% (95/172)
# 0 2 Epoch: 27 | ANN: testLoss: 1.2045 | testAcc: 45.3125% (29/64)
# 1 2 Epoch: 27 | ANN: testLoss: 1.2124 | testAcc: 45.6897% (53/116)
#
#
# 0 3 Epoch: 28 | ANN: trainLoss: 1.0670 | trainAcc: 56.2500% (36/64)
# 1 3 Epoch: 28 | ANN: trainLoss: 1.1025 | trainAcc: 51.5625% (66/128)
# 2 3 Epoch: 28 | ANN: trainLoss: 1.1045 | trainAcc: 51.1628% (88/172)
# 0 2 Epoch: 28 | ANN: testLoss: 1.2197 | testAcc: 50.0000% (32/64)
# 1 2 Epoch: 28 | ANN: testLoss: 1.2108 | testAcc: 49.1379% (57/116)
#
#
# 0 3 Epoch: 29 | ANN: trainLoss: 1.0929 | trainAcc: 56.2500% (36/64)
# 1 3 Epoch: 29 | ANN: trainLoss: 1.1082 | trainAcc: 48.4375% (62/128)
# 2 3 Epoch: 29 | ANN: trainLoss: 1.0715 | trainAcc: 49.4186% (85/172)
# 0 2 Epoch: 29 | ANN: testLoss: 1.2080 | testAcc: 50.0000% (32/64)
# 1 2 Epoch: 29 | ANN: testLoss: 1.2122 | testAcc: 48.2759% (56/116)
# ---------------------------------------------
# Converting using MaxNorm
# 100%|██████████| 3/3 [00:00<00:00,  6.38it/s]
# 100%|██████████| 3/3 [00:00<00:00,  6.80it/s]
# ANN accuracy: Test: 48.2800%
# SNN accuracy: max_norm: 44.8276%

# %%
# Evaluate models and visualize results
# Get ANN predictions
ann_model.eval()
ann_predictions = []
true_labels = []
with torch.no_grad():
    for inputs, targets in data_loader(test_data, test_label, batch=BATCH_SIZE, shuffle=False, drop=False):
        outputs = ann_model(inputs)
        _, predicted = outputs.max(1)
        ann_predictions.extend(predicted.cpu().numpy())
        true_labels.extend(targets.cpu().numpy())

# Get SNN predictions
snn_predictions = []
with torch.no_grad():
    for inputs, targets in data_loader(test_data, test_label, batch=BATCH_SIZE, shuffle=False, drop=False):
        for m in snn_model.modules():
            if hasattr(m, 'reset'):
                m.reset()
        for t in range(TIME_STEPS):
            if t == 0:
                outputs = snn_model(inputs)
            else:
                outputs += snn_model(inputs)
        _, predicted = outputs.max(1)
        snn_predictions.extend(predicted.cpu().numpy())

# Confusion Matrix for ANN
cm_ann = confusion_matrix(true_labels, ann_predictions)
disp_ann = ConfusionMatrixDisplay(confusion_matrix=cm_ann)
disp_ann.plot()
plt.title('Confusion Matrix - ANN')
plt.show()

# Confusion Matrix for SNN
cm_snn = confusion_matrix(true_labels, snn_predictions)
disp_snn = ConfusionMatrixDisplay(confusion_matrix=cm_snn)
disp_snn.plot()
plt.title('Confusion Matrix - SNN')
plt.show()

print('\n')
print('ANN accuracy: Test: %.4f%%' % (test_acc * 100))
print('SNN accuracy: max_norm: %.4f%%' % (max_norm_acc[-1] * 100))
# Out:
# ANN accuracy: Test: 48.2800%
# SNN accuracy: max_norm: 44.8276%
